# %%
## add <a class="anchor" id="line_1"></a> 
## to your title (Markdown Cell) like:
## # Example of title N1 <a class="anchor" id="line_1"></a>
## ## Example of title N2 <a class="anchor" id="line_3"></a>
## ...
## Then add your Content Table in formst of hyprtlink [text](link): 

## * [Title N1](#line_1)
## * [Title N2](#line_2)
## * [Title N3](#line_3)
## ...

## Done (This works when opened locally on your computer)

# %% [markdown]
# # Table of contents <a class="anchor" id="line_0"></a>
# * [Example number 1](#line_1)
# * [Example number 2](#line_2)
# * [END](#line_end)

# %% [markdown]
# # [Title Number 1](#line_0) <a class="anchor" id="line_1"></a>

# %%
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code

# %% [markdown]
# ## [Title number 2](#line_0) <a class="anchor" id="line_2"></a>

# %%
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 

# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 
# Some text Some text Some text Some text Some text 

# Some Code 
# Some Code 
# Some Code
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code 
# Some Code

# %% [markdown]
# # [END](#line_0) <a class="anchor" id="line_end"></a>
